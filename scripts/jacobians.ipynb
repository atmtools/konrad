# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from typhon.arts import xml


plt.style.use(typhon.plots.styles('typhon'))

K = xml.load('results/jacobian.xml')
p = xml.load('results/plev.xml')

# fig, ax = plt.subplots()
# sm = ax.pcolormesh(p, p, K, cmap='seismic')
# cb = fig.colorbar(sm, label='K / VMR')
# ax.set_yscale('log')
# ax.set_xscale('log')
# ax.set_xlim(p[0], p[-1])
# ax.set_ylim(p[0], p[-1])
# ax.yaxis.set_major_formatter(typhon.plots.HectoPascalLogFormatter())
# ax.yaxis.set_minor_formatter(typhon.plots.HectoPascalLogFormatter())
# ax.xaxis.set_major_formatter(typhon.plots.HectoPascalLogFormatter())
# ax.xaxis.set_minor_formatter(typhon.plots.HectoPascalLogFormatter())
# ax.set_ylabel('Pressure [hPa]')
# ax.set_xlabel('Pressure [hPa]')
# ax.set_aspect('equal')
# typhon.plots.center_colorbar(cb)

fig, ax = plt.subplots(figsize=(6, 8))
typhon.plots.profile_p_log(p, K)
ax.set_ylim(p.max(), p.min())
ax.set_xlabel('K/ VMR')

# %%
K = xml.load('results/jacobian.xml')
p = xml.load('results/plev.xml')

# fig, ax = plt.subplots()
# sm = ax.pcolormesh(p, p, K, cmap='seismic')
# cb = fig.colorbar(sm, label='K / VMR')
# ax.set_yscale('log')
# ax.set_xscale('log')
# ax.set_xlim(p[0], p[-1])
# ax.set_ylim(p[0], p[-1])
# ax.yaxis.set_major_formatter(typhon.plots.HectoPascalLogFormatter())
# ax.yaxis.set_minor_formatter(typhon.plots.HectoPascalLogFormatter())
# ax.xaxis.set_major_formatter(typhon.plots.HectoPascalLogFormatter())
# ax.xaxis.set_minor_formatter(typhon.plots.HectoPascalLogFormatter())
# ax.set_ylabel('Pressure [hPa]')
# ax.set_xlabel('Pressure [hPa]')
# ax.set_aspect('equal')
# typhon.plots.center_colorbar(cb)

fig, ax = plt.subplots(figsize=(6, 8))
typhon.plots.profile_p_log(p, K)
ax.set_ylim(p.max(), p.min())
ax.set_xlabel('K/ VMR')
